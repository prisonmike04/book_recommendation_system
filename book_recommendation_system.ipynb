# %% [markdown]
# # **Books recommendation system | collaboratives based**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('/content/BX-Books.csv', sep=';', on_bad_lines='skip', encoding='latin-1', engine='python')
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.shape
# Out:
# (33385, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',  'Image-URL-L']]

# %%
books.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# ...

# %%
books.rename(columns={'Book-Title':'title', 'Book-Author':'author', 'Year-Of-Publication':'year ', 'Publisher':'Publisher', 'Image-URL-L':'img_url'}, inplace=True)

# %%
books.head(2)
# Out:
#          ISBN                title                author  year   \
# 0  0195153448  Classical Mythology    Mark P. O. Morford   2002
# 1  0002005018         Clara Callan  Richard Bruce Wright   2001
#
#                  Publisher                                            img_url
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...

# %%
users = pd.read_csv('/content/BX-Users.csv', sep=';', on_bad_lines='skip', encoding='latin-1', engine='python')
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (237924, 3)

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
ratings = pd.read_csv('/content/BX-Book-Ratings.csv', sep=';', on_bad_lines='skip', encoding='latin-1', engine='python')
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (403031, 3)

# %%
ratings.columns
# Out:
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
ratings = ratings.rename(columns={'User-ID':'user_id', 'Book-Rating':'rating'})

# %%
ratings.head()
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
ratings['user_id'].nunique()
# Out:
# 37767

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13600
# 35859      5850
# 278418     4533
# 76352      3367
# 16795      2948
#           ...
# 57551         1
# 23843         1
# 57538         1
# 57533         1
# 276725        1
# Name: count, Length: 37767, dtype: int64

# %%
ratings['user_id'].unique().shape
# Out:
# (37767,)

# %%
ratings['user_id'].count()
# Out:
# 403031

# %%
x = ratings['user_id'].value_counts() > 200

# %%
x.head(10)
# Out:
# user_id
# 11676     True
# 35859     True
# 278418    True
# 76352     True
# 16795     True
# 36836     True
# 52584     True
# 55492     True
# 60244     True
# 69697     True
# Name: count, dtype: bool

# %%
x[x].shape
# Out:
# (294,)

# %%
y = x[x].index

# %%
y
# Out:
# Index([ 11676,  35859, 278418,  76352,  16795,  36836,  52584,  55492,  60244,
#         69697,
#        ...
#         83287,  56360,  50547,  88793,  33145,  73681,  59727,  28634,  44296,
#          9856],
#       dtype='int64', name='user_id', length=294)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings.shape
# Out:
# (179240, 3)

# %%
rating_with_books = ratings.merge(books, on='ISBN')

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                    Publisher  \
# 0    Mark P. O. Morford   2002     Oxford University Press
# 1  Richard Bruce Wright   2001       HarperFlamingo Canada
# 2          Carlo D'Este   1991             HarperPerennial
# 3      Gina Bari Kolata   1999        Farrar Straus Giroux
# 4       E. J. W. Barber   1999  W. W. Norton &amp; Company
#
#                                              img_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
rating_with_books.head(100)
# Out:
#     user_id        ISBN  rating  \
# 0    277427  002542730X      10
# 1      3363  002542730X       0
# 2     11676  002542730X       6
# 3     12538  002542730X      10
# 4     13552  002542730X       0
# ..      ...         ...     ...
# 95    83637  0060930535       0
# 96    85426  0060930535       0
# 97    85526  0060930535       8
# 98    86202  0060930535       0
# 99    87555  0060930535       0
#
#                                                 title              author  \
# 0   Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 1   Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 2   Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 3   Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 4   Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# ..                                                ...                 ...
# ...

# %%
rating_with_books.shape
# Out:
# (80082, 8)

# %%
num_rating = rating_with_books.groupby('title')['rating'].count().reset_index()

# %%
num_rating.head()
# Out:
#                                                title  rating
# 0   Beyond IBM: Leadership Marketing and Finance ...       1
# 1                                       It Takes Two       1
# 2   Q-Space (Star Trek The Next Generation, Book 47)       6
# 3                       Tales of Terror and Suspense       1
# 4  'O Au No Keia: Voices from Hawai'I's Mahu and ...       2

# %%
num_rating.rename(columns={"rating":"no_of_rating"},inplace = True)

# %%
num_rating.head()
# Out:
#                                                title  no_of_rating
# 0   Beyond IBM: Leadership Marketing and Finance ...             1
# 1                                       It Takes Two             1
# 2   Q-Space (Star Trek The Next Generation, Book 47)             6
# 3                       Tales of Terror and Suspense             1
# 4  'O Au No Keia: Voices from Hawai'I's Mahu and ...             2

# %%
final_rating =  rating_with_books.merge(num_rating, on='title')

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
#
#    year                   Publisher  \
# 0   1994  John Wiley &amp; Sons Inc
# 1   1994  John Wiley &amp; Sons Inc
# 2   1994  John Wiley &amp; Sons Inc
# 3   1994  John Wiley &amp; Sons Inc
# 4   1994  John Wiley &amp; Sons Inc
#
#                                              img_url  no_of_rating
# ...

# %%
final_rating.shape
# Out:
# (80082, 9)

# %%
final_rating = final_rating[final_rating['no_of_rating']>=50]

# %%
final_rating.head(10)
# Out:
#     user_id        ISBN  rating                          title  \
# 58   277427  0060930535       0  The Poisonwood Bible: A Novel
# 59      254  0060930535       0  The Poisonwood Bible: A Novel
# 60     6251  0060930535       0  The Poisonwood Bible: A Novel
# 61     7346  0060930535       0  The Poisonwood Bible: A Novel
# 62    11676  0060930535       0  The Poisonwood Bible: A Novel
# 63    13273  0060930535       9  The Poisonwood Bible: A Novel
# 64    16634  0060930535       0  The Poisonwood Bible: A Novel
# 65    16795  0060930535       4  The Poisonwood Bible: A Novel
# 66    17950  0060930535       0  The Poisonwood Bible: A Novel
# 67    19664  0060930535       0  The Poisonwood Bible: A Novel
#
#                 author  year   Publisher  \
# 58  Barbara Kingsolver   1999  Perennial
# 59  Barbara Kingsolver   1999  Perennial
# 60  Barbara Kingsolver   1999  Perennial
# 61  Barbara Kingsolver   1999  Perennial
# 62  Barbara Kingsolver   1999  Perennial
# ...

# %%
final_rating.sample(10)
# Out:
#        user_id        ISBN  rating  \
# 3077      8245  0553268880       9
# 15880    87141  0440221471       0
# 19243     4017  0060928336       0
# 21264    87141  0440224675       0
# 21230    16795  0440224675       5
# 5784      7346  0440214041       0
# 15870    56856  0440221471       8
# 9730     69232  044651652X       9
# 9839     52853  0446676098       0
# 19260    21014  0060928336       8
#
#                                                  title               author  \
# 3077                               The Prince of Tides           Pat Conroy
# 15880                                 The Runaway Jury         JOHN GRISHAM
# 19243  Divine Secrets of the Ya-Ya Sisterhood: A Novel        Rebecca Wells
# 21264                                         Hannibal        Thomas Harris
# 21230                                         Hannibal        Thomas Harris
# 5784                                 The Pelican Brief         John Grisham
# ...

# %%
final_rating.shape
# Out:
# (3327, 9)

# %%
final_rating.drop_duplicates(['title','user_id'], inplace = True)
# Out:
# <ipython-input-46-f5d5baaa6ea2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_rating.drop_duplicates(['title','user_id'], inplace = True)

# %%
final_rating.shape
# Out:
# (3171, 9)

# %%
book_pivot = final_rating.pivot(index='title', columns='user_id', values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    NaN     NaN     NaN
# A Painted House                                        NaN     NaN     NaN
# A Prayer for Owen Meany                                NaN     NaN     NaN
# A Time to Kill                                         NaN     NaN     NaN
# Angels &amp; Demons                                    NaN     NaN     NaN
# Bridget Jones's Diary                                  0.0     NaN     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel        NaN     NaN     NaN
# Fried Green Tomatoes at the Whistle Stop Cafe          NaN     NaN     NaN
# Girl with a Pearl Earring                              0.0     NaN     NaN
# Good in Bed                                            NaN     NaN     NaN
# Hannibal                                               NaN     NaN     NaN
# ...

# %%
book_pivot.shape
# Out:
# (53, 280)

# %%
book_pivot.fillna(0, inplace = True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1st to Die: A Novel                                    0.0     0.0     0.0
# A Painted House                                        0.0     0.0     0.0
# A Prayer for Owen Meany                                0.0     0.0     0.0
# A Time to Kill                                         0.0     0.0     0.0
# Angels &amp; Demons                                    0.0     0.0     0.0
# Bridget Jones's Diary                                  0.0     0.0     0.0
# Divine Secrets of the Ya-Ya Sisterhood: A Novel        0.0     0.0     0.0
# Fried Green Tomatoes at the Whistle Stop Cafe          0.0     0.0     0.0
# Girl with a Pearl Earring                              0.0     0.0     0.0
# Good in Bed                                            0.0     0.0     0.0
# Hannibal                                               0.0     0.0     0.0
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <53x280 sparse matrix of type '<class 'numpy.float64'>'
# 	with 886 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # **CLUSTERING NEAREST NEIGHOUR ALGORITHM**

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
print(book_pivot.shape)
# Out:
# (53, 280)

# %%
index = 237
if index < book_pivot.shape[0]:
    distances, suggestions = model.kneighbors(book_pivot.iloc[index, :].values.reshape(1, -1), n_neighbors=6)
else:
    print(f"Index {index} is out of bounds for DataFrame with {book_pivot.shape[0]} rows.")
# Out:
# Index 237 is out of bounds for DataFrame with 53 rows.

# %%
import random

index = random.randint(0, book_pivot.shape[0] - 1)
distances, suggestions = model.kneighbors(book_pivot.iloc[index, :].values.reshape(1, -1), n_neighbors=6)

# %%
distances
# Out:
# array([[ 0.        , 39.47150871, 40.03748244, 40.74309757, 41.02438299,
#         41.06093034]])

# %%
suggestions
# Out:
# array([[17, 38, 52, 39, 49, 41]])

# %%
for i in range(len(suggestions)):
  print(book_pivot.index[suggestions[i]])
# Out:
# Index(['Me Talk Pretty One Day',
#        'The Perfect Storm : A True Story of Men Against the Sea',
#        'Wild Animus', 'The Poisonwood Bible: A Novel', 'When the Wind Blows',
#        'The Rainmaker'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# 'A Time to Kill'

# %%
book_pivot.index
# Out:
# Index(['1st to Die: A Novel', 'A Painted House', 'A Prayer for Owen Meany',
#        'A Time to Kill', 'Angels &amp; Demons', 'Bridget Jones's Diary',
#        'Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#        'Fried Green Tomatoes at the Whistle Stop Cafe',
#        'Girl with a Pearl Earring', 'Good in Bed', 'Hannibal',
#        'Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))',
#        'House of Sand and Fog', 'Interview with the Vampire', 'Jurassic Park',
#        'Life of Pi', 'Me Talk Pretty One Day', 'Message in a Bottle',
#        'STONES FROM THE RIVER', 'Snow Falling on Cedars', 'Summer Sisters',
#        'The Bonesetter's Daughter', 'The Brethren',
#        'The Bridges of Madison County', 'The Chamber', 'The Client',
#        'The Da Vinci Code', 'The Firm',
#        'The Girls' Guide to Hunting and Fishing', 'The Horse Whisperer',
# ...

# %%
books_name = book_pivot.index

# %%
import pickle
import os

artifact_dir = 'artifacts'

if not os.path.exists(artifact_dir):
    os.makedirs(artifact_dir)

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))

pickle.dump(books_name,open('artifacts/books_name.pkl','wb'))

pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))

pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_books(book_name):
  book_id = np.where(book_pivot.index==book_name)[0][0]
  distances, suggestions = model.kneighbors(book_pivot.iloc[book_id, :].values.reshape(1, -1), n_neighbors=6)

  for i in range(len(suggestions)):
    books_name = book_pivot.index[suggestions[i]]
    for j in books:
      print(j)

# %%
# prompt: i want the above code to be in such a way that when i use the below code then i get similar books recommended

import numpy as np
# Load the model and data
model = pickle.load(open('artifacts/model.pkl','rb'))
books_name = pickle.load(open('artifacts/books_name.pkl','rb'))
final_rating = pickle.load(open('artifacts/final_rating.pkl','rb'))
book_pivot = pickle.load(open('artifacts/book_pivot.pkl','rb'))

# Get the book name from the user
book_name = input("Enter the name of a book: ")

# Recommend similar books
def recommend_books(book_name):
  book_id = np.where(book_pivot.index==book_name)[0][0]
  distances, suggestions = model.kneighbors(book_pivot.iloc[book_id, :].values.reshape(1, -1), n_neighbors=6)

  for i in range(len(suggestions)):
    recommended_book_name = book_pivot.index[suggestions[i]]
    print(f"Recommended book: {recommended_book_name}")

recommend_books(book_name)
# Out:
# Enter the name of a book: Harry Potter and the Chamber of Secrets (Book 2)
# Recommended book: Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))',
#        'The Bonesetter's Daughter', 'Wild Animus',
#        'The Poisonwood Bible: A Novel', 'The Client'],
#       dtype='object', name='title')

# %%
books_name = 'Harry Potter and the Chamber of Secrets (Book 2)'
recommend_books(books_name)
# Out:
# Recommended book: Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))',
#        'The Bonesetter's Daughter', 'Wild Animus',
#        'The Poisonwood Bible: A Novel', 'The Client'],
#       dtype='object', name='title')

# %%
np.where(book_pivot.index=='Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# (array([11]),)

# %%
np.where(book_pivot.index== '2nd Chance')
# Out:
# (array([], dtype=int64),)

# %%
from google.colab import files

file_path = '/content/artifacts/model.pkl'

files.download(file_path)
